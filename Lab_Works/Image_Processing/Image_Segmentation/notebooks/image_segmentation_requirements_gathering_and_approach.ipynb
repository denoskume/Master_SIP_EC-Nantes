# %% [markdown]
# <div style="display:flex; justify-content:space-between; align-items:center; width:100%; margin:8px 0 24px 0;">
#   <div style="text-align:left;">
#     <img src="https://www.ec-nantes.fr/medias/photo/logocn-rvb_1648479844750-png?ID_FICHE=178994&amp;INLINE=FALSE" alt="Centrale Nantes" style="height:72px; width:auto;">
#   </div>
#   <div style="text-align:right; font-size:18px; font-weight:600; color:#17324d; line-height:1.35;">
#     MSc. CORO DASSIP
#   </div>
# </div>
#
# <div style="border:2px solid #333; padding:14px 20px; margin:15px auto 25px auto; width:85%; max-width:900px; box-sizing:border-box; text-align:center;">
#   <h1 style="margin:0;"><b>Image Segmentation</b></h1>
# </div>

# %% [markdown]
# ## Requirements and Approach
#
# Translate every segmentation task into an explicit input representation, algorithm/parameter choice, mask or region output, diagnostic figure, and validation criterion.

# %% [markdown]
# ## Global Requirements
#
# - Use repository-relative paths and module-local data.
# - Define foreground/background conventions explicitly.
# - Preserve binary-mask semantics through morphology and interpolation-sensitive operations.
# - Separate preprocessing, segmentation, post-processing, region analysis, and evaluation.
# - Use Dice/IoU or related metrics when ground truth is available.
# - Save representative diagnostic figures and validate output properties/files.

# %% [markdown]
# ## 1. Segmentation Problem Formulation
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 2. Load the Lab Images
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 3. Histograms and Why Thresholding Can Work
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 4. Manual Global Thresholding
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 5. Threshold Sensitivity
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 6. Otsu Thresholding
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 7. Gaussian Smoothing Before Thresholding
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 8. Adaptive Thresholding
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 9. Morphological Processing
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 10. Structuring Elements
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 11. Erosion and Dilation
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 12. Opening and Closing
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 13. Morphological Gradient
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 14. Hole Filling
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 15. Connected Components
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 16. Remove Small Components
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 17. Contours
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 18. Region Properties
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 19. Color Segmentation
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 20. Edge-Based Segmentation Intuition
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 21. Distance Transform
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 22. Watershed Segmentation
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 23. Ground Truth and Segmentation Metrics
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 24. Dice vs IoU Relationship
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 25. Under-Segmentation vs Over-Segmentation
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 26. End-to-End Binary Segmentation Pipeline
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 27. Segmentation Method Selection Criteria
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## 28. Integrated Segmentation Workflow
#
# **Requirement:** implement this segmentation stage transparently and reproducibly.
#
# **Approach:** use the mathematical/algorithmic model in the matching Theory section and the executable Implementation section.
#
# **Acceptance criterion:** masks, regions, and metrics are internally consistent and visually plausible for the stated task.

# %% [markdown]
# ## Requirement-to-Code Traceability
#
# The same ordered task list is used across all four notebooks so every requirement maps directly to a numbered implementation section.
