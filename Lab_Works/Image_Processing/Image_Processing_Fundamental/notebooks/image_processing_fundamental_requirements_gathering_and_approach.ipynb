# %% [markdown]
# <div style="display:flex; justify-content:space-between; align-items:center; width:100%; margin:8px 0 24px 0;">
#   <div style="text-align:left;">
#     <img src="https://www.ec-nantes.fr/medias/photo/logocn-rvb_1648479844750-png?ID_FICHE=178994&amp;INLINE=FALSE" alt="Centrale Nantes" style="height:72px; width:auto;">
#   </div>
#   <div style="text-align:right; font-size:18px; font-weight:600; color:#17324d; line-height:1.35;">
#     MSc. CORO DASSIP
#   </div>
# </div>
#
# <div style="border:2px solid #333; padding:14px 20px; margin:15px auto 25px auto; width:85%; max-width:900px; box-sizing:border-box; text-align:center;">
#   <h1 style="margin:0;"><b>Image Processing Fundamental</b></h1>
# </div>

# %% [markdown]
# ## Requirements and Approach
#
# This document defines the numerical and data-handling requirements for the core image-processing operations used throughout the laboratory series.
#
# The specification covers image representation, coordinate conventions, channel semantics, data types, dynamic range, safe arithmetic, histogram/statistical analysis, synthetic degradation, file encoding, quantitative comparison, and reproducible output generation. Each operation must preserve clearly defined input/output contracts and support direct numerical validation.

# %% [markdown]
# ## Global Requirements
#
# - Use repository-relative paths only.
# - Keep source data in `data/` and generated figures in `outputs/figures/`.
# - Preserve dtype and dynamic-range semantics intentionally.
# - Prefer explicit numerical operations before black-box abstractions.
# - Save meaningful visual evidence and perform numerical checks.
# - Keep the notebook executable from top to bottom.

# %% [markdown]
# ## 1. Data and Output Paths
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 2. Sampling and Quantization Experiments
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 3. Pixel Coordinates and Array Representation
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 4. Image Representation Modes
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 5. Load and Inspect Real Images
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 6. Dimensions, Resolution, Aspect Ratio, and Channels
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 7. Data Types, Bit Depth, Dynamic Range, and Memory
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 8. Display Scaling and Visualization Control
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 9. Pixel Access and Safe Modification
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 10. Regions of Interest (ROI)
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 11. Pixel Neighborhoods
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 12. RGB Channel Decomposition
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 13. RGB and BGR Conventions
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 14. RGB-to-Grayscale Conversion
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 15. Image Statistics
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 16. Intensity Histograms
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 17. Dynamic Range and Min-Max Normalization
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 18. `uint8` Arithmetic, Overflow, Clipping, and Floating Point
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 19. Noise Model Simulation
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 20. Image Comparison Metrics
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 21. Lossless vs Lossy Image Encoding
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 22. Standard Image Inspection Workflow
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## 23. Validation Checks
#
# **Requirement:** implement the task explicitly and reproducibly.
#
# **Approach:** apply the stated numerical operation with explicit dtype, range, and validation controls.
#
# **Acceptance criterion:** the task produces valid arrays/results and any required figure or numerical check succeeds.

# %% [markdown]
# ## Requirement-to-Code Traceability
#
# Task numbering and titles are identical across the four notebooks. Every requirement maps directly to the same numbered section of the Implementation notebook.
